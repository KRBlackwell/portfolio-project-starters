# %% [markdown]
# # Sharing visualizations and code
#
# ## trinket, pygal, and svg
# I came across this website trinket.io, thanks to a comment on stackoverflow. It allows you to write a lot of python and share it without having to download anything. It provides example code, and the below stacked line chart is one of them. You can embed the code and output as I've done with IPython's IFrame here. trinket gives you an html snippet you can copy and paste if you use the share icon ⠪ and click "</> Embed."\
#  \
# An upside is you can write and share code with anyone. A downside is you may not have the entirety of a package available.\
# For example, dir(pygal) shows you that you can only use the following from the package: Bar, HorizontalBar, Line, Pie, Radar, StackedBar, StackedHorizontalBar, StackedLine, and XY. The __doc__ returned is also empty. You're also not able to use all of what's available within StackedLine. Like render_to_file

# %%
from IPython.display import IFrame
IFrame('https://trinket.io/python/c9d33ef70d', 1200, 500)
# Out:
#         <iframe
#             width="1200"
#             height="500"
#             src="https://trinket.io/python/c9d33ef70d"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## The chart that I get from trinket.io is different from the chart I get below
# What I noticed is trinket doesn't allow you to use everything available from pygal, and it's providing different defaults.
# See the chart from trinket if for some reason it doesn't display above:\
# <img width="500" height="250" src="...... "/>

# %% [markdown]
# ## The code directly in the notebook.
# You can copy and paste the code into your IDE or an editor or a notebook to run yourself.\
# IPython's display SVG will help us display the result. However, the result appears "upside-down" compared with the above. Likely because of the different defaults and how it's creating and rendering the svg in the website.

# %%
# !pip install pygal
import pygal
print("pygal version:", pygal.__version__)
from IPython.display import SVG, display
#I added "width, height, and explicit_size" to make the image smaller
#style=DarkStyle to match the trinket one and make it not so bright

# Our data is a list of series.
# Each series is a list with a label and a list of data points
data = [["Firefox", [None, None, 0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1]],
        ["Chrome",  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3]],
        ["IE",      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1]],
        ["Others",  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5]]]


stackedline_chart = pygal.StackedLine(fill=True, width=500, height=250, explicit_size=True, style=pygal.style.DarkStyle)
stackedline_chart.title = "Browser usage evolution (in %)"
stackedline_chart.x_labels = map(str, range(2002, 2013))

for label, data_points in data:
    stackedline_chart.add(label, data_points)
# Out:
# pygal version: 3.0.4

# %%
display(SVG(stackedline_chart.render()))
